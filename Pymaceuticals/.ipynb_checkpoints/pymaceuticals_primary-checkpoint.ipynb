# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from pprint import pprint

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combined_data = pd.merge(mouse_metadata, study_results, on="Mouse ID")

# Display the data table for preview
combined_data.head(25)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16          0
# 1      k403     Ramicane    Male          21          16          5
# 2      k403     Ramicane    Male          21          16         10
# 3      k403     Ramicane    Male          21          16         15
# 4      k403     Ramicane    Male          21          16         20
# 5      k403     Ramicane    Male          21          16         25
# 6      k403     Ramicane    Male          21          16         30
# 7      k403     Ramicane    Male          21          16         35
# 8      k403     Ramicane    Male          21          16         40
# 9      k403     Ramicane    Male          21          16         45
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# ...

# %%
# Checking the number of mice.
combined_data['Mouse ID'].nunique()
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_counts = combined_data['Mouse ID'].duplicated().sum()

duplicate_counts
# Out:
# 1644

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicates = combined_data['Mouse ID'].duplicated()

pprint(duplicates)
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1888     True
# 1889     True
# 1890     True
# 1891     True
# 1892     True
# Name: Mouse ID, Length: 1893, dtype: bool

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_data = combined_data.drop_duplicates(subset="Mouse ID", keep="first")

cleaned_data
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
cleaned_data['Mouse ID'].count()
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Group the data by Drug Regimen
grouped_data = combined_data.groupby('Drug Regimen')

# mean, median, variance, standard deviation, and SEM of the tumor volume.
summary_stats = pd.DataFrame({
    'Mean': grouped_data['Tumor Volume (mm3)'].mean(),
    'Median': grouped_data['Tumor Volume (mm3)'].median(),
    'Variance': grouped_data['Tumor Volume (mm3)'].var(),
    'Standard Deviation': grouped_data['Tumor Volume (mm3)'].std(),
    'SEM': grouped_data['Tumor Volume (mm3)'].sem()
})

# Display the summary statistics table
summary_stats
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070            6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
tumor_summary = combined_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std', 'sem'])

tumor_summary
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
    # Count all line for each drug regimine
drug_counts = combined_data['Drug Regimen'].value_counts()

# Create the bar plot
drug_counts.plot(kind='bar', figsize=(8, 5))

# Set the plot title and axis labels
plt.title('Number of Timepoints per Drug Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoint')

# Display the plot
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.

# Get the drug regimens and their counts
regimens = drug_counts.index
counts = drug_counts.values

# Create the py plot
plt.figure(figsize=(10, 6))
plt.bar(regimens, counts)

# Set the plot title and axis labels
plt.title('Number of Timepoints per Drug Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoint')
plt.xticks(rotation='vertical')

# Display the plot
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
# Count the number of male and female mice
gender_counts = combined_data['Sex'].value_counts()

# Create the pie plot
gender_counts.plot(kind='pie', figsize=(8, 5), autopct='%1.1f%%')

# Labels
plt.ylabel('Sex')

# Display the plot
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
# Count the number of male and female mice
gender_counts = combined_data['Sex'].value_counts()

# Get the gender labels and their counts
genders = gender_counts.index
counts = gender_counts.values

# Create the pie plot
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=genders, autopct='%1.1f%%')

# Set the plot title
plt.ylabel('Sex')

# Display the plot
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
treatment_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
filtered_data = combined_data[combined_data['Drug Regimen'].isin(treatment_regimens)]

# Start by getting the last (greatest) timepoint for each mouse
final_tumor_volume = filtered_data.groupby('Mouse ID')['Timepoint'].max().reset_index()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
final_tumor_volume = pd.merge(final_tumor_volume, filtered_data, on=['Mouse ID', 'Timepoint'])

final_tumor_volume
# Out:
#    Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0      a203         45    Infubinol  Female          20          23
# 1      a251         45    Infubinol  Female          21          25
# 2      a275         45     Ceftamin  Female          20          28
# 3      a411         45     Ramicane    Male           3          22
# 4      a444         45     Ramicane  Female          10          25
# ..      ...        ...          ...     ...         ...         ...
# 95     y769         45     Ceftamin  Female           6          27
# 96     y793         45    Capomulin    Male          17          17
# 97     y865         45     Ceftamin    Male          23          26
# 98     z578         45     Ramicane    Male          11          16
# 99     z581         45    Infubinol  Female          24          25
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            67.973419                 2
# 1            65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
empty_tumor = []

# Locate the rows which contain mice on each drug and get the tumor volumes
for regimen in treatment_regimens:
    # Filter the final tumor volume data for the current regimen
    regimen_data = final_tumor_volume.loc[final_tumor_volume['Drug Regimen'] == regimen, 'Tumor Volume (mm3)']
    
    empty_tumor.append(regimen_data)
    
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = regimen_data.quantile([0.25, 0.5, 0.75])
lower_quartile = quartiles[0.25]
upper_quartile = quartiles[0.75]
iqr = upper_quartile - lower_quartile

    
outliers = regimen_data[(regimen_data < lower_bound) | (regimen_data > upper_bound)]

print(f"Regimen: {regimen}")
print(f"Tumor Volumes: {regimen_data.values}")
    # add subset 

    
    # Determine outliers using upper and lower bounds
lower_bound = lower_quartile - (1.5 * iqr)
upper_bound = upper_quartile + (1.5 * iqr)
print(f"Potential Outliers: {outliers}")
# Out:
# Regimen: Ceftamin
# Tumor Volumes: [62.99935619 45.         56.05774909 55.74282869 48.72207785 47.7846818
#  61.84902336 68.92318457 67.74866174 57.91838132 46.78453491 59.85195552
#  64.29983003 59.74190064 61.43389223 64.19234114 45.         52.92534846
#  45.         67.52748237 45.         64.63494887 61.38666032 68.59474498
#  64.72983655]
# Potential Outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
plt.figure(figsize=(10, 6))
plt.boxplot(empty_tumor, labels=treatment_regimens)
plt.xlabel("Drug Regimen")
plt.ylabel("Final Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
# New varriable for mouse ID I509
mouse_l509 = combined_data[combined_data['Mouse ID'] == 'l509']

# Create the line plot
plt.figure(figsize=(10, 6))
plt.plot(mouse_l509['Timepoint'], mouse_l509['Tumor Volume (mm3)'])

# Set the plot title and axis labels
plt.title('Capomulin treatment of Mouse l509')
plt.xlabel('Timepoint (days)')
plt.ylabel('Tumor Volume (mm3)')

# Display the plot
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
# Filter only for capomulin
capomulin_data = combined_data[combined_data['Drug Regimen'] == 'Capomulin']

# Create the scatterplot
plt.figure(figsize=(10, 6))
plt.scatter(capomulin_data['Weight (g)'], capomulin_data['Tumor Volume (mm3)'], marker='o')

# Set the plot title and axis labels
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')

# Display the plot
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

plt.figure(figsize=(10, 6))
plt.scatter(capomulin_data['Weight (g)'], capomulin_data['Tumor Volume (mm3)'], marker='o')

# Set the plot title and axis labels
plt.title('Mouse Weight vs Tumor Volume - Capomulin Regimen')
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')

# Perform linear regression
slope, intercept, rvalue, pvalue, stderr = st.linregress(capomulin_data['Weight (g)'], capomulin_data['Tumor Volume (mm3)'])
plt.plot(capomulin_data['Weight (g)'], slope * capomulin_data['Weight (g)'] + intercept, color='red')

# Display the plot
plt.show()
